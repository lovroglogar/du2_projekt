# %%
import matplotlib.pyplot as plt
import pickle

# %%
# file = open('dub2_data\\pickled\\celeba_hq_256', 'rb')
# file = open('dub2_data\\pickled\\avg_blurred_images', 'rb')
file = open('dub2_data\\pickled\\gauss_blurred_images', 'rb')
images = pickle.load(file)
file.close()

# %%
images.shape
# Out:
# (29941, 3, 64, 64)

# %%
plt.imshow(images[1].transpose(1, 2, 0))

# %%
from faces_dataset import FacesDataset
from torchvision import transforms
from torch.utils.data import DataLoader

# %%
dataset = FacesDataset('dub2_data\\pickled\\celeba_hq_256', transform=transforms.ToTensor())

# %%
dataloader = DataLoader(dataset, shuffle=True, batch_size=128)

# %%
next(iter(dataloader)).shape
# Out:
# torch.Size([128, 3, 64, 64])
